# %%
import numpy as np
import cv2
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt

# %%
filename = "hyttest2.png"
img = cv2.imread(filename)
gray = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)

# %%
plt.subplot(1,2,1)
plt.title("Original image")
plt.imshow(img)
plt.subplot(1,2,2)
plt.title("gray scaled image")
plt.imshow(gray)
plt.show()
print(f"gray scaled image matrix: \n {gray}")
# Out:
# gray scaled image matrix:
#  [[ 23  22  24 ...  99 100 100]
#  [ 28  28  29 ...  98 101 104]
#  [ 35  36  36 ...  99  99  98]
#  ...
#  [ 31  31  31 ...  29  28  27]
#  [ 30  29  29 ...  29  28  29]
#  [ 31  29  30 ...  26  27  28]]

# %%
gray = np.float32(gray)
print(gray)
dst =  cv2.cornerHarris(gray , 2,3,0.04)
# Out:
# [[ 23.  22.  24. ...  99. 100. 100.]
#  [ 28.  28.  29. ...  98. 101. 104.]
#  [ 35.  36.  36. ...  99.  99.  98.]
#  ...
#  [ 31.  31.  31. ...  29.  28.  27.]
#  [ 30.  29.  29. ...  29.  28.  29.]
#  [ 31.  29.  30. ...  26.  27.  28.]]

# %%
#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# %%
# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.2*dst.max()]=[0,0,250]

# %%
cv2.imshow('dst',img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
