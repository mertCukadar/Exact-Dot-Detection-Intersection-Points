# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd

# %%
img = cv2.imread("original-image.png")
gray_scaled = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_scaled)

# %%
gray_scaled = np.array(gray_scaled)

# %%
inverse_scaled = np.absolute(gray_scaled - 255/1)

# %%
plt.imshow(inverse_scaled)

# %%
cv2.
